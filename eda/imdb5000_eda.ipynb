# %%
import pandas as pd

# %%
movies = pd.read_csv('../data/imdb5000.csv')

# %%
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
movies.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# ...

# %%
movies.iloc[0]
# Out:
# color                                                                    Color
# director_name                                                    James Cameron
# num_critic_for_reviews                                                     723
# duration                                                                   178
# director_facebook_likes                                                      0
# actor_3_facebook_likes                                                     855
# actor_2_name                                                  Joel David Moore
# actor_1_facebook_likes                                                    1000
# gross                                                              7.60506e+08
# genres                                         Action|Adventure|Fantasy|Sci-Fi
# actor_1_name                                                       CCH Pounder
# movie_title                                                            Avatar
# ...

# %%
# Could dummify genres, plot_keywords

# %%
movies2 = movies.copy()
movies2.genres = movies2.genres.apply(lambda x: x.split('|'))
movies2.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                                genres  \
# 0                  1000.0  760505847.0  [Action, Adventure, Fantasy, Sci-Fi]
# ...

# %%
movies2.plot_keywords = movies2.plot_keywords.fillna(value='')
movies2.plot_keywords = movies2.plot_keywords.apply(lambda x: x.split('|'))

# %%
movies2.loc[0]
# Out:
# color                                                                    Color
# director_name                                                    James Cameron
# num_critic_for_reviews                                                     723
# duration                                                                   178
# director_facebook_likes                                                      0
# actor_3_facebook_likes                                                     855
# actor_2_name                                                  Joel David Moore
# actor_1_facebook_likes                                                    1000
# gross                                                              7.60506e+08
# genres                                    [Action, Adventure, Fantasy, Sci-Fi]
# actor_1_name                                                       CCH Pounder
# movie_title                                                            Avatar
# ...

# %%
movies2.describe().transpose()
# Out:
#                             count          mean           std      min  \
# num_critic_for_reviews     4993.0  1.401943e+02  1.216017e+02     1.00
# duration                   5028.0  1.072011e+02  2.519744e+01     7.00
# director_facebook_likes    4939.0  6.865092e+02  2.813329e+03     0.00
# actor_3_facebook_likes     5020.0  6.450098e+02  1.665042e+03     0.00
# actor_1_facebook_likes     5036.0  6.560047e+03  1.502076e+04     0.00
# gross                      4159.0  4.846841e+07  6.845299e+07   162.00
# num_voted_users            5043.0  8.366816e+04  1.384853e+05     5.00
# cast_total_facebook_likes  5043.0  9.699064e+03  1.816380e+04     0.00
# facenumber_in_poster       5030.0  1.371173e+00  2.013576e+00     0.00
# num_user_for_reviews       5022.0  2.727708e+02  3.779829e+02     1.00
# budget                     4551.0  3.975262e+07  2.061149e+08   218.00
# title_year                 4935.0  2.002471e+03  1.247460e+01  1916.00
# ...

# %%
movies3 = movies2.copy()

# %%
movies3 = movies3[['movie_title','director_name','actor_1_name','actor_2_name','actor_3_name','genres','plot_keywords','language','country','content_rating','title_year']]

# %%
movies3[movies3.director_name.isnull()]
# Out:
#                                     movie_title director_name  \
# 177                     Miami Vice                        NaN
# 260                     The A-Team                        NaN
# 404                       Hannibal                        NaN
# 459                      Daredevil                        NaN
# 479                      Bewitched                        NaN
# 537                    Constantine                        NaN
# 543                           Life                        NaN
# 593                  Sleepy Hollow                        NaN
# 645              Last Man Standing                        NaN
# 685                    The Missing                        NaN
# 757            Rules of Engagement                        NaN
# 816     Sabrina, the Teenage Witch                        NaN
# 826               Sex and the City                        NaN
# 833               Anger Management                        NaN
# ...

# %%
# Movies where director name is null are not actually movies, but TV shows!
# Should drop these rows, since we're only considered with movie data
# Dropping 104 rows out of 5043

# %%
movies3 = movies3[movies3['director_name'].notnull()]

# %%
movies3.head()
# Out:
#                                          movie_title      director_name  \
# 0                                            Avatar       James Cameron
# 1          Pirates of the Caribbean: At World's End      Gore Verbinski
# 2                                           Spectre          Sam Mendes
# 3                             The Dark Knight Rises   Christopher Nolan
# 4  Star Wars: Episode VII - The Force Awakens    ...        Doug Walker
#
#       actor_1_name      actor_2_name          actor_3_name  \
# 0      CCH Pounder  Joel David Moore             Wes Studi
# 1      Johnny Depp     Orlando Bloom        Jack Davenport
# 2  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4      Doug Walker        Rob Walker                   NaN
#
#                                  genres  \
# 0  [Action, Adventure, Fantasy, Sci-Fi]
# 1          [Action, Adventure, Fantasy]
# 2         [Action, Adventure, Thriller]
# ...

# %%
movies3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4939 entries, 0 to 5042
# Data columns (total 11 columns):
# movie_title       4939 non-null object
# director_name     4939 non-null object
# actor_1_name      4932 non-null object
# actor_2_name      4928 non-null object
# actor_3_name      4919 non-null object
# genres            4939 non-null object
# plot_keywords     4939 non-null object
# language          4928 non-null object
# country           4936 non-null object
# content_rating    4674 non-null object
# title_year        4935 non-null float64
# dtypes: float64(1), object(10)
# memory usage: 463.0+ KB

# %%
movies3 = movies3.drop('language', axis=1)

# %%
movies3.head()
# Out:
#                                          movie_title      director_name  \
# 0                                            Avatar       James Cameron
# 1          Pirates of the Caribbean: At World's End      Gore Verbinski
# 2                                           Spectre          Sam Mendes
# 3                             The Dark Knight Rises   Christopher Nolan
# 4  Star Wars: Episode VII - The Force Awakens    ...        Doug Walker
#
#       actor_1_name      actor_2_name          actor_3_name  \
# 0      CCH Pounder  Joel David Moore             Wes Studi
# 1      Johnny Depp     Orlando Bloom        Jack Davenport
# 2  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4      Doug Walker        Rob Walker                   NaN
#
#                                  genres  \
# 0  [Action, Adventure, Fantasy, Sci-Fi]
# 1          [Action, Adventure, Fantasy]
# 2         [Action, Adventure, Thriller]
# ...

# %%
movies3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4939 entries, 0 to 5042
# Data columns (total 10 columns):
# movie_title       4939 non-null object
# director_name     4939 non-null object
# actor_1_name      4932 non-null object
# actor_2_name      4928 non-null object
# actor_3_name      4919 non-null object
# genres            4939 non-null object
# plot_keywords     4939 non-null object
# country           4936 non-null object
# content_rating    4674 non-null object
# title_year        4935 non-null float64
# dtypes: float64(1), object(9)
# memory usage: 424.4+ KB

# %%
movies3[movies3.title_year.isnull()]
# Out:
#                                             movie_title        director_name  \
# 4     Star Wars: Episode VII - The Force Awakens    ...          Doug Walker
# 279                            10,000 B.C.               Christopher Barnard
# 2765                      Towering Inferno                    John Blanchard
# 2870         Del 1 - Män som hatar kvinnor                 Niels Arden Oplev
#
#          actor_1_name   actor_2_name  actor_3_name  \
# 4         Doug Walker     Rob Walker           NaN
# 279       Mathew Buck            NaN           NaN
# 2765     Martin Short  Andrea Martin  Joe Flaherty
# 2870  Michael Nyqvist   David Dencik    Lena Endre
#
#                                   genres plot_keywords country content_rating  \
# 4                          [Documentary]            []     NaN            NaN
# 279                             [Comedy]            []     NaN            NaN
# 2765                            [Comedy]            []  Canada            NaN
# ...

# %%
movies3 = movies3[movies3['title_year'].notnull()]

# %%
movies3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4935 entries, 0 to 5042
# Data columns (total 10 columns):
# movie_title       4935 non-null object
# director_name     4935 non-null object
# actor_1_name      4928 non-null object
# actor_2_name      4925 non-null object
# actor_3_name      4917 non-null object
# genres            4935 non-null object
# plot_keywords     4935 non-null object
# country           4934 non-null object
# content_rating    4674 non-null object
# title_year        4935 non-null float64
# dtypes: float64(1), object(9)
# memory usage: 424.1+ KB

# %%
movies3[movies3.content_rating.isnull()]
# Out:
#                                          movie_title          director_name  \
# 98                              Godzilla Resurgence            Hideaki Anno
# 199   Harry Potter and the Deathly Hallows: Part II              Matt Birch
# 204                             Godzilla Resurgence            Hideaki Anno
# 206    Harry Potter and the Deathly Hallows: Part I              Matt Birch
# 242                    Asterix at the Olympic Games      Frédéric Forestier
# 489                                       Evolution   Lucile Hadzihalilovic
# 810     Xi you ji zhi: Sun Wukong san da Baigu Jing          Pou-Soi Cheang
# 1044                                The Tooth Fairy            Chuck Bowman
# 1178                   Animal Kingdom: Let's go Ape          Jamel Debbouze
# 1329                       Baahubali: The Beginning          S.S. Rajamouli
# 1347                    Dragon Nest: Warriors' Dawn            Yuefeng Song
# ...

# %%
movies4 = movies3.copy()

# %%
movies4 = movies3[['movie_title','director_name','genres','plot_keywords']]

# %%
movies4.head()
# Out:
#                                  movie_title      director_name  \
# 0                                    Avatar       James Cameron
# 1  Pirates of the Caribbean: At World's End      Gore Verbinski
# 2                                   Spectre          Sam Mendes
# 3                     The Dark Knight Rises   Christopher Nolan
# 5                               John Carter      Andrew Stanton
#
#                                  genres  \
# 0  [Action, Adventure, Fantasy, Sci-Fi]
# 1          [Action, Adventure, Fantasy]
# 2         [Action, Adventure, Thriller]
# 3                    [Action, Thriller]
# 5           [Action, Adventure, Sci-Fi]
#
#                                        plot_keywords
# 0       [avatar, future, marine, native, paraplegic]
# 1  [goddess, marriage ceremony, marriage proposal...
# 2          [bomb, espionage, sequel, spy, terrorist]
# 3  [deception, imprisonment, lawlessness, police ...
# 5  [alien, american civil war, male nipple, mars,...

# %%
from preprocessing import preprocess

# %%
processed_movies = preprocess(movies4)

# %%
processed_movies.tags.loc[50]
# Out:
# ['Baz_Luhrmann',
#  'Drama',
#  'Romance',
#  'ingratitude',
#  'mansion',
#  'party',
#  'title appears in writing',
#  'tragedy']

# %%
processed_movies.tags.loc[1]
# Out:
# ['Gore_Verbinski',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'goddess',
#  'marriage ceremony',
#  'marriage proposal',
#  'pirate',
#  'singapore']

# %%
def replace_space(tags):
    '''
    Replaces spaces with underscores for the tags in the movies.tags column
    of movies dataframe
    '''
    for tag in tags:
        tag.replace(' ','_')
    return tags

# %%
processed_movies.head()
# Out:
#                                  movie_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 5                               John Carter
#
#                                                 tags
# 0  [James_Cameron, Action, Adventure, Fantasy, Sc...
# 1  [Gore_Verbinski, Action, Adventure, Fantasy, g...
# 2  [Sam_Mendes, Action, Adventure, Thriller, bomb...
# 3  [Christopher_Nolan, Action, Thriller, deceptio...
# 5  [Andrew_Stanton, Action, Adventure, Sci-Fi, al...

# %%
processed_movies.head(50)
# Out:
#                                      movie_title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 5                                   John Carter
# 6                                  Spider-Man 3
# 7                                       Tangled
# 8                       Avengers: Age of Ultron
# 9        Harry Potter and the Half-Blood Prince
# 10           Batman v Superman: Dawn of Justice
# 11                             Superman Returns
# 12                            Quantum of Solace
# 13   Pirates of the Caribbean: Dead Man's Chest
# 14                              The Lone Ranger
# 15                                 Man of Steel
# 16     The Chronicles of Narnia: Prince Caspian
# 17                                 The Avengers
# 18  Pirates of the Caribbean: On Stranger Tides
# ...

# %%
processed_movies.tags.loc[0]
# Out:
# ['James_Cameron',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'avatar',
#  'future',
#  'marine',
#  'native',
#  'paraplegic']

# %%
processed_movies.tags.loc[1]
# Out:
# ['Gore_Verbinski',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'goddess',
#  'marriage ceremony',
#  'marriage proposal',
#  'pirate',
#  'singapore']

# %%
processed_movies.tags.loc[48], processed_movies.tags.loc[49], processed_movies.tags.loc[1905]
# Out:
# (['J.J._Abrams',
#   'Action',
#   'Adventure',
#   'Sci-Fi',
#   'admiral',
#   'captain',
#   'manhunt',
#   'mission',
#   'space'],
#  ['Bryan_Singer',
#   'Adventure',
#   'Fantasy',
#   'bean',
#   'giant',
#   'king',
#   'no opening credits',
#   'princess'],
#  ['Kirk_Jones',
#   'Comedy',
#   'Family',
#   'Fantasy',
#   'father',
#   'governess',
#   'magic',
#   'nanny',
#   'widower'])

# %%
processed_movies
# Out:
#                                        movie_title  \
# 0                                          Avatar
# 1        Pirates of the Caribbean: At World's End
# 2                                         Spectre
# 3                           The Dark Knight Rises
# 5                                     John Carter
# 6                                    Spider-Man 3
# 7                                         Tangled
# 8                         Avengers: Age of Ultron
# 9          Harry Potter and the Half-Blood Prince
# 10             Batman v Superman: Dawn of Justice
# 11                               Superman Returns
# 12                              Quantum of Solace
# 13     Pirates of the Caribbean: Dead Man's Chest
# 14                                The Lone Ranger
# 15                                   Man of Steel
# 16       The Chronicles of Narnia: Prince Caspian
# 17                                   The Avengers
# 18    Pirates of the Caribbean: On Stranger Tides
# ...

# %%
processed_movies.iloc[600:650]
# Out:
#                                 movie_title  \
# 610                               Stardust
# 611                   Seven Years in Tibet
# 612                            The Dilemma
# 613                            Bad Company
# 614                                   Doom
# 615                                  I Spy
# 616                  Underworld: Awakening
# 617                           Rock of Ages
# 618                             Hart's War
# 619                           Killer Elite
# 620                             Rollerball
# 621              Ballistic: Ecks vs. Sever
# 622                              Hard Rain
# 623                          Osmosis Jones
# 624        Legends of Oz: Dorothy's Return
# 625                               Blackhat
# 626  Sky Captain and the World of Tomorrow
# 627                       Basic Instinct 2
# 628                            Escape Plan
# 629                 The Legend of Hercules
# 630                   The Sum of All Fears
# ...
